# %% [markdown]
# #**Deep Learning Homework 5: *Autoencoders***
# ### MSc Computer Science, Data Science, Cybersecurity Computer Engeneering @UniPD
# ### 2nd semester - 6 ECTS
# ### Prof. Nicolò Navarin & Prof. Alessandro Sperduti
# ---
#
#
# In this homework, we will deal with _dimensionality reduction_ and learn how to develop a simple _Autoencoder_.
# In the first part, we will learn how to develop a simple shallow autoencoder, then we will develop a deep version. Next, we will experiment with the application of autoencoder on denoising data task (denoising-autoencoder). Finally, we will apply this model to sequential domains, considering the IMDB dataset seen in HW4.

# %%
# import the usual libriaries
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

np.random.seed(42)

# %% [markdown]
# ### Load Dataset
# We load the CIFAR-10 dataset, using `tf.keras.datasets`. The dataset contains 60,000 training images and 10,000 testing images.
# The images are originally in RGB format, but we will convert them to grayscale for convenience. The value of each pixel is between 0 and 255, and it represents a point of an image of size 32 x 32. We will normalize all values between 0 and 1, and we will flatten the 32x32 images into vectors of size 1024.
# Finally, since no validation set is defined, we split the test set in a validation set and a new test set.

# %%
cifar_10 = keras.datasets.cifar10
(X_train_full, _), (x_test, _) = cifar_10.load_data() # The dataset is already divede in test and training

X_train_full, x_test = np.mean(X_train_full, -1), np.mean(x_test, -1)

X_train_full = X_train_full.astype('float32') / 255
x_test = x_test.astype('float32') / 255

X_train_full = X_train_full.reshape((len(X_train_full), np.prod(X_train_full.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# We extract the first 10000 samples of the training set, to use them as the validation set
x_valid, x_train = X_train_full[:10000], X_train_full[10000:]
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 11s 0us/step

# %% [markdown]
# ## [TO COMPLETE] Exercise 5.1: Singular Value Decomposition
#
# Similar to Principal component analysis (PCA), Singular Value Decomposition (SVD) is a standard linear dimensionality reduction method. They both linealry combine the features of the original high-dimensional dataset and project them into a lower-dimensional space, ideally retaing most of thier intrinsic properties.
#
# In this first part of the HW, we will focus our attention on SVD decomposition and its performances. Given a matrix $X$, the SVD decomposes it into the product of two unitary matrices $V$ and $U$ and a rectangular diagonal matrix of singular values $S$:
#
# $$ X=V \cdot S \cdot U^T.$$
#
# The SVD is already implemented in NumPy as `np.linalg.svd`. In our case, the $X$ matrix will represent the training set, where each row is a sample (therefore the number of columns will be the number of input features). However, notice that the $X$ matrix has a huge number of rows (we have 50,000 input samples) and only 784 columns. If you are using the _Colab_ free plan, the quantity of available RAM may not be sufficient to compute the SVD of $X$. Therefore, to ease memory consumption and numerical stability, we resort to one property of the SVD and compute its equivalent version from the covariance matrix $C= X^T \cdot X$, that can be decomposed as:
#
# $$ C= U \cdot S^2 \cdot U^T$$
#
# Since we need just the matrix $U$ to compute the compressed version of our data, this trick turns out to be a quick and good solution.

# %%
def SVD(X, k):
  # Compute covariance matrix
  C = np.dot(X.T, X)
  # SVD decomposition
  U, s_sqr, U_T = np.linalg.svd(C, full_matrices=False)
  # Limit the number columns of U to k
  U_k=U[:,:k]
  return U_k

# %% [markdown]
# Let's define the `ENCODING_DIM`, that will be the size of the compressed version of input data, and project the low-dimensional versions of the training set and the test set as well.

# %%
ENCODING_DIM = 120

U_k = SVD(x_train, ENCODING_DIM)

x_training_svd = np.dot(x_train, U_k)
x_test_svd = np.dot(x_test, U_k)

# %% [markdown]
# We now reconstruct back the original input and check how much information was lost due to the compression. We do so by computing the mean squared error between the original input and the reconstruction, and by plotting the reconstructed images.

# %%
x_training_reco = np.dot(x_training_svd, U_k.T)
x_test_reco = np.dot(x_test_svd, U_k.T)

# %%
accuracy_train = ((x_train - x_training_reco)**2).mean()
accuracy_test = ((x_test - x_test_reco)**2).mean()

print("Training mse: %.5f" % ( accuracy_train))
print("Test mse: %.5f" % ( accuracy_test))
# Out:
# Training mse: 0.00372
# Test mse: 0.00375

# %%
def plot_img(n, images_sets: list, title=""):
  plt.figure(figsize=(20, 4))
  for i in range(n):
    for set_idx, images in enumerate(images_sets):
      ax = plt.subplot(len(images_sets), n, i + 1 + set_idx*n)
      plt.imshow(images[i].reshape(32, 32))
      plt.gray()
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)
  plt.suptitle(title)
  plt.show()

# %% [markdown]
# Let's see how well the input can be reconstructed by displaying a few of the input images and the corresponding reconstructions. Obviously, all these evaluations have to be done on the test set.
#
# The first row of images corresponds to input data, while the second one contains the reconstructions.

# %%
plot_img(10, [x_test, x_test_reco], title = "Original (top) vs Reconstructed (bottom)")

# %% [markdown]
# **[TO COMPLETE]**: What happens by varying the `ENCODING_DIM`? Try it out and discuss the results in this cell.
#
# _Answer:_ The reconstruction improves proportional to the value of ENCODING_DIM. As expected, the lower this value is, the more information we ate expected to lose, and thus, the worse the reconstruction of the images

# %% [markdown]
# ## [TO COMPLETE] Exercise 5.2: Shallow Linear Autoencoder
# Let's define a model that consists of a single fully-connected neural layer. The hidden layer and the output layer act as the encoder and the decoder, respectively. Differently than the previous HW when we used `Keras.Sequential()`, here we define the two parts of the model (encoder and decoder) separately and then we create the final model.

# %%
ENCODING_DIM = 256
INPUT_DIM = x_train.shape[-1]

input_img = tf.keras.layers.Input(shape=(INPUT_DIM,))
# Define the encoder...
encoded = tf.keras.layers.Dense(ENCODING_DIM, activation='linear')(input_img)

# ...the decoder...
decoded = tf.keras.layers.Dense(INPUT_DIM, activation='linear')(encoded)

# and the autoencoder
autoencoder = tf.keras.models.Model(input_img, decoded)

# In order to visualize the learned encoding, define a model that computes the 
# two parts separately.
encoder = tf.keras.models.Model(input_img, encoded)
encoded_input = tf.keras.layers.Input(shape=(ENCODING_DIM,))
decoder_layer = autoencoder.layers[-1]
decoder = tf.keras.models.Model(encoded_input, decoder_layer(encoded_input))

# Finally, let's call the compile method
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005), loss='mse')

# %% [markdown]
# Print the model summary.

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1024)]            0
#
#  dense (Dense)               (None, 256)               262400
#
#  dense_1 (Dense)             (None, 1024)              263168
#
# =================================================================
# Total params: 525,568
# Trainable params: 525,568
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model.

# %%
history = autoencoder.fit(x_train, x_train, epochs=15, batch_size=512, shuffle=True, validation_data=(x_valid, x_valid))
# Out:
# Epoch 1/15
# 79/79 [==============================] - 4s 39ms/step - loss: 0.2132 - val_loss: 0.0312
# Epoch 2/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0315 - val_loss: 0.0230
# Epoch 3/15
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0192 - val_loss: 0.0170
# Epoch 4/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0154 - val_loss: 0.0142
# Epoch 5/15
# 79/79 [==============================] - 3s 36ms/step - loss: 0.0131 - val_loss: 0.0123
# Epoch 6/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0115 - val_loss: 0.0110
# Epoch 7/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0106 - val_loss: 0.0103
# Epoch 8/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0093 - val_loss: 0.0101
# Epoch 9/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0102 - val_loss: 0.0081
# Epoch 10/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0077 - val_loss: 0.0075
# Epoch 11/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 12/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0067 - val_loss: 0.0066
# Epoch 13/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0067 - val_loss: 0.0062
# Epoch 14/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0060 - val_loss: 0.0058
# Epoch 15/15
# 79/79 [==============================] - 3s 37ms/step - loss: 0.0058 - val_loss: 0.0057

# %% [markdown]
# Plot the loss and the accuracy curves on the validation set, and the accuracy on the test set.

# %%
def plot_loss(history):
  plt.figure(figsize=(10,6))
  plt.plot(history.epoch,history.history['loss'])
  plt.plot(history.epoch,history.history['val_loss'])
  plt.grid()
  plt.title('loss')

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("Test mse: %.5f" % (scores))
# Out:
# 313/313 - 1s - loss: 0.0057 - 871ms/epoch - 3ms/step
# Test mse: 0.00568

# %%
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

plot_img(10, [x_test, decoded_imgs], title = "Original (top) vs Reconstructed (bottom)")
# Out:
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# **[TO COMPLETE]** Check the results and compare them versus the results obtained with the SVD. Give an explanation of the relation between the results obtained  by the shallow linear autoencoder and the ones obtained by the SVD decomposition.
#
#
# _Answer:_ After testing on the same encoding dimension, we notice that SVD provides better results - the encoder optimization algorithm only finds a local minimum, on a non-convex function, while the SVD uses matrix decomposition to find the results. Moreover, the linear activation functions might not be the best fit for our data

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.3: Shallow Non-linear Autoencoders
#
# **[TO COMPLETE]** Replicate the code of Exercise 5.2 but in this case, instead of using linear activation functions use non-linear ones. Choose the most appropriate non-linear function, and motivate your choice. Then discuss the results in relation to those obtained in Exercise 5.2.
#
# Insert your code and theoretical discussion into cells immediately below this one.

# %% [markdown]
# I have tried both of the classical sigmoid and softmax activation functions. Then, I compare the test MSE and loss with the linear activation encoder.

# %%
# Sigmoid activation function
input_img = tf.keras.layers.Input(shape=(INPUT_DIM,))
# Define the encoder...
encoded = tf.keras.layers.Dense(ENCODING_DIM, activation='sigmoid')(input_img)

# ...the decoder...
decoded = tf.keras.layers.Dense(INPUT_DIM, activation='sigmoid')(encoded)

# and the autoencoder
autoencoder = tf.keras.models.Model(input_img, decoded)

# In order to visualize the learned encoding, define a model that computes the 
# two parts separately.
encoder = tf.keras.models.Model(input_img, encoded)
encoded_input = tf.keras.layers.Input(shape=(ENCODING_DIM,))
decoder_layer = autoencoder.layers[-1]
decoder = tf.keras.models.Model(encoded_input, decoder_layer(encoded_input))

# Finally, let's call the compile method
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005), loss='mse')

history = autoencoder.fit(x_train, x_train, epochs=15, batch_size=512, shuffle=True, validation_data=(x_valid, x_valid))
print("----------------------------------------------------------------------------------------------")
scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("MSE for sigmoid on test: %.5f" % (scores))
plot_loss(history)
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

plot_img(10, [x_test, decoded_imgs], title = "Original (top) vs Reconstructed (bottom)")
# Out:
# Epoch 1/15
# 79/79 [==============================] - 4s 44ms/step - loss: 0.0349 - val_loss: 0.0217
# Epoch 2/15
# 79/79 [==============================] - 3s 42ms/step - loss: 0.0214 - val_loss: 0.0183
# Epoch 3/15
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0160 - val_loss: 0.0150
# Epoch 4/15
# 79/79 [==============================] - 3s 40ms/step - loss: 0.0137 - val_loss: 0.0125
# Epoch 5/15
# 79/79 [==============================] - 4s 52ms/step - loss: 0.0122 - val_loss: 0.0117
# Epoch 6/15
# 79/79 [==============================] - 5s 58ms/step - loss: 0.0115 - val_loss: 0.0119
# Epoch 7/15
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0099 - val_loss: 0.0096
# Epoch 8/15
# 79/79 [==============================] - 3s 40ms/step - loss: 0.0094 - val_loss: 0.0088
# Epoch 9/15
# 79/79 [==============================] - 3s 40ms/step - loss: 0.0090 - val_loss: 0.0083
# Epoch 10/15
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0084 - val_loss: 0.0084
# Epoch 11/15
# 79/79 [==============================] - 3s 40ms/step - loss: 0.0079 - val_loss: 0.0107
# Epoch 12/15
# 79/79 [==============================] - 3s 40ms/step - loss: 0.0077 - val_loss: 0.0076
# Epoch 13/15
# 79/79 [==============================] - 3s 40ms/step - loss: 0.0073 - val_loss: 0.0068
# Epoch 14/15
# 79/79 [==============================] - 3s 40ms/step - loss: 0.0106 - val_loss: 0.0074
# Epoch 15/15
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0070 - val_loss: 0.0066
# ----------------------------------------------------------------------------------------------
# 313/313 - 1s - loss: 0.0066 - 944ms/epoch - 3ms/step
# MSE for sigmoid on test: 0.00660
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 2ms/step

# %%
# Softmax activation
input_img = tf.keras.layers.Input(shape=(INPUT_DIM,))
# Define the encoder...
encoded = tf.keras.layers.Dense(ENCODING_DIM, activation='softmax')(input_img)

# ...the decoder...
decoded = tf.keras.layers.Dense(INPUT_DIM, activation='softmax')(encoded)

# and the autoencoder
autoencoder = tf.keras.models.Model(input_img, decoded)

# In order to visualize the learned encoding, define a model that computes the 
# two parts separately.
encoder = tf.keras.models.Model(input_img, encoded)
encoded_input = tf.keras.layers.Input(shape=(ENCODING_DIM,))
decoder_layer = autoencoder.layers[-1]
decoder = tf.keras.models.Model(encoded_input, decoder_layer(encoded_input))

# Finally, let's call the compile method
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005), loss='mse')

history = autoencoder.fit(x_train, x_train, epochs=15, batch_size=512, shuffle=True, validation_data=(x_valid, x_valid))
print("----------------------------------------------------------------------------------------------")
scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("MSE for softmax on test: %.5f" % (scores))
plot_loss(history)
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

plot_img(10, [x_test, decoded_imgs], title = "Original (top) vs Reconstructed (bottom)")
# Out:
# Epoch 1/15
# 79/79 [==============================] - 4s 43ms/step - loss: 0.2800 - val_loss: 0.2822
# Epoch 2/15
# 79/79 [==============================] - 3s 42ms/step - loss: 0.2800 - val_loss: 0.2822
# Epoch 3/15
# 79/79 [==============================] - 3s 42ms/step - loss: 0.2800 - val_loss: 0.2822
# Epoch 4/15
# 79/79 [==============================] - 3s 41ms/step - loss: 0.2800 - val_loss: 0.2822
# Epoch 5/15
# 79/79 [==============================] - 3s 42ms/step - loss: 0.2799 - val_loss: 0.2821
# Epoch 6/15
# 79/79 [==============================] - 3s 41ms/step - loss: 0.2799 - val_loss: 0.2821
# Epoch 7/15
# 79/79 [==============================] - 3s 41ms/step - loss: 0.2799 - val_loss: 0.2820
# Epoch 8/15
# 79/79 [==============================] - 3s 42ms/step - loss: 0.2798 - val_loss: 0.2820
# Epoch 9/15
# 79/79 [==============================] - 3s 41ms/step - loss: 0.2798 - val_loss: 0.2820
# Epoch 10/15
# 79/79 [==============================] - 3s 41ms/step - loss: 0.2798 - val_loss: 0.2820
# Epoch 11/15
# 79/79 [==============================] - 3s 42ms/step - loss: 0.2798 - val_loss: 0.2820
# Epoch 12/15
# 79/79 [==============================] - 3s 41ms/step - loss: 0.2797 - val_loss: 0.2819
# Epoch 13/15
# 79/79 [==============================] - 3s 41ms/step - loss: 0.2797 - val_loss: 0.2819
# Epoch 14/15
# 79/79 [==============================] - 3s 42ms/step - loss: 0.2797 - val_loss: 0.2819
# Epoch 15/15
# 79/79 [==============================] - 3s 41ms/step - loss: 0.2797 - val_loss: 0.2819
# ----------------------------------------------------------------------------------------------
# 313/313 - 1s - loss: 0.2830 - 953ms/epoch - 3ms/step
# MSE for softmax on test: 0.28303
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# It becomes obvious that out of the two, the sigmoid activation function performs way better, with a MSE of 0.00534 and loss of roughly 0.007. But, probably because sigmoid tends to converge slower and has a higher tendency to produce vaishing gradients, the linear activation still outperforms the other two.

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.4: Deep Autoencoder
# **[TO COMPLETE]** Build a deep version of the Autoencoder defined above. The autoencoder has to use at least 5 layers. The model will use $n$ layers for encoding, and $n-1$ for decoding. The layers sizes of the encoding part decrease at each layer (e.g., `INPUT_DIM->128->64`, where 64 is the encoding dim). The decoding part layers dimensions progression turns out to be mirrored (e.g., `128->INPUT_DIM`, the final overall structure recalls an hourglass ⏳).
# As usual, print the model summary, the loss curves during the training, the achieved loss on the test set, and some input images with the corresponding decoding.

# %%
INPUT_DIM = x_train.shape[-1]

input_img = tf.keras.layers.Input(shape=(INPUT_DIM,))

# Define the encoding layers
encoded = tf.keras.layers.Dense(256, activation='relu')(input_img)
encoded = tf.keras.layers.Dense(128, activation='relu')(encoded)
encoded = tf.keras.layers.Dense(64, activation='relu')(encoded)
# Define the decoding layers
decoded = tf.keras.layers.Dense(128, activation='relu')(encoded)
decoded = tf.keras.layers.Dense(256, activation='relu')(decoded)
decoded = tf.keras.layers.Dense(INPUT_DIM, activation='sigmoid')(decoded)

autoencoder = tf.keras.models.Model(input_img, decoded) #[TO COMPLETE]

autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.005), loss='mse')

# %%
autoencoder.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 1024)]            0
#
#  dense_6 (Dense)             (None, 256)               262400
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dense_9 (Dense)             (None, 128)               8320
#
#  dense_10 (Dense)            (None, 256)               33024
#
#  dense_11 (Dense)            (None, 1024)              263168
#
# =================================================================
# Total params: 608,064
# Trainable params: 608,064
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = autoencoder.fit(x_train, x_train, epochs= 30, batch_size= 256, shuffle=True, validation_data=(x_valid, x_valid))
# Out:
# Epoch 1/30
# 157/157 [==============================] - 5s 28ms/step - loss: 0.0347 - val_loss: 0.0272
# Epoch 2/30
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0262 - val_loss: 0.0243
# Epoch 3/30
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0229 - val_loss: 0.0217
# Epoch 4/30
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0209 - val_loss: 0.0216
# Epoch 5/30
# 157/157 [==============================] - 7s 47ms/step - loss: 0.0197 - val_loss: 0.0194
# Epoch 6/30
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0192 - val_loss: 0.0192
# Epoch 7/30
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0191 - val_loss: 0.0189
# Epoch 8/30
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0185 - val_loss: 0.0181
# Epoch 9/30
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0176 - val_loss: 0.0172
# Epoch 10/30
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0170 - val_loss: 0.0177
# Epoch 11/30
# 157/157 [==============================] - 7s 43ms/step - loss: 0.0168 - val_loss: 0.0168
# Epoch 12/30
# 157/157 [==============================] - 6s 38ms/step - loss: 0.0170 - val_loss: 0.0193
# Epoch 13/30
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0163 - val_loss: 0.0162
# Epoch 14/30
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0158 - val_loss: 0.0166
# Epoch 15/30
# 157/157 [==============================] - 6s 36ms/step - loss: 0.0157 - val_loss: 0.0163
# Epoch 16/30
# 157/157 [==============================] - 6s 38ms/step - loss: 0.0156 - val_loss: 0.0156
# Epoch 17/30
# 157/157 [==============================] - 6s 40ms/step - loss: 0.0152 - val_loss: 0.0155
# Epoch 18/30
# 157/157 [==============================] - 6s 35ms/step - loss: 0.0151 - val_loss: 0.0152
# Epoch 19/30
# 157/157 [==============================] - 5s 30ms/step - loss: 0.0150 - val_loss: 0.0153
# Epoch 20/30
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0150 - val_loss: 0.0151
# Epoch 21/30
# 157/157 [==============================] - 5s 34ms/step - loss: 0.0149 - val_loss: 0.0155
# Epoch 22/30
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0150 - val_loss: 0.0150
# Epoch 23/30
# 157/157 [==============================] - 4s 27ms/step - loss: 0.0149 - val_loss: 0.0155
# Epoch 24/30
# 157/157 [==============================] - 5s 30ms/step - loss: 0.0151 - val_loss: 0.0151
# Epoch 25/30
# 157/157 [==============================] - 5s 33ms/step - loss: 0.0148 - val_loss: 0.0151
# Epoch 26/30
# 157/157 [==============================] - 5s 35ms/step - loss: 0.0148 - val_loss: 0.0151
# Epoch 27/30
# 157/157 [==============================] - 5s 30ms/step - loss: 0.0149 - val_loss: 0.0152
# Epoch 28/30
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0149 - val_loss: 0.0150
# Epoch 29/30
# 157/157 [==============================] - 6s 35ms/step - loss: 0.0148 - val_loss: 0.0150
# Epoch 30/30
# 157/157 [==============================] - 6s 37ms/step - loss: 0.0148 - val_loss: 0.0151

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test, x_test, verbose=2)
print("test mse: %.5f" % (scores))
# Out:
# 313/313 - 1s - loss: 0.0151 - 984ms/epoch - 3ms/step
# test mse: 0.01505

# %%
decoded_imgs = autoencoder.predict(x_test)

plot_img(10, [x_test, decoded_imgs], title = "Original (top) vs Reconstructed (bottom)")
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# ## [TO COMPLETE] Exercise 5.5: Denoising Autoencoder
#
# Let's now use a shallow autoencoder to denoise the input data. The idea is that only meaningful information will be encoded, thus filtering out useless noise.
# Firstly, define a noisy input by adding some gaussian noise to our input data. We define a noise factor that can be used to modify the amount of noise to add to the input data. Check how much it influences the denoising capability of the autoencoder.

# %%
noise_factor = 0.3

x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_valid_noisy = x_valid + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_valid.shape)

# we still have to be sure that the color values are in the [0,1] range:
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)
x_valid_noisy = np.clip(x_valid_noisy, 0., 1.)

# %% [markdown]
# Plot some noisy inputs:

# %%
plot_img(10, [x_test_noisy, x_test], title = "Noisy (top) vs Original (bottom)")

# %% [markdown]
# **[TO COMPLETE]** Define a shallow autoencoder able to compute a de-noised version of the input (use a noise_factor $\geq 0.3$).

# %%
INPUT_DIM = x_train.shape[-1]

input_img = tf.keras.layers.Input(shape=(INPUT_DIM,))
#[TO COMPLETE]
encoded = tf.keras.layers.Dense(ENCODING_DIM, activation='sigmoid')(input_img)
decoded = tf.keras.layers.Dense(INPUT_DIM, activation='sigmoid')(encoded)
autoencoder = tf.keras.models.Model(input_img, decoded)
opt = tf.keras.optimizers.Adam(learning_rate=0.003)
autoencoder.compile(optimizer = opt, loss = 'mse') #[TO COMPLETE]

# %%
autoencoder.summary()
# Out:
# Model: "model_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 1024)]            0
#
#  dense_14 (Dense)            (None, 256)               262400
#
#  dense_15 (Dense)            (None, 1024)              263168
#
# =================================================================
# Total params: 525,568
# Trainable params: 525,568
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **[TO COMPLETE]** Train the model by passing the noisy input and the clean target.

# %%
history = autoencoder.fit(x_train_noisy, x_train, epochs=50, batch_size=512, shuffle=True, validation_data=(x_valid_noisy, x_valid)) #[TO COMPLETE]
# Out:
# Epoch 1/50
# 79/79 [==============================] - 4s 41ms/step - loss: 0.0376 - val_loss: 0.0251
# Epoch 2/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0216 - val_loss: 0.0192
# Epoch 3/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0178 - val_loss: 0.0167
# Epoch 4/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0161 - val_loss: 0.0153
# Epoch 5/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0148 - val_loss: 0.0150
# Epoch 6/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0143 - val_loss: 0.0140
# Epoch 7/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0135 - val_loss: 0.0133
# Epoch 8/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0132 - val_loss: 0.0134
# Epoch 9/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0127 - val_loss: 0.0138
# Epoch 10/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0125 - val_loss: 0.0124
# Epoch 11/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0123 - val_loss: 0.0121
# Epoch 12/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0120 - val_loss: 0.0126
# Epoch 13/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0119 - val_loss: 0.0163
# Epoch 14/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0117 - val_loss: 0.0124
# Epoch 15/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0116 - val_loss: 0.0118
# Epoch 16/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0115 - val_loss: 0.0117
# Epoch 17/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0114 - val_loss: 0.0117
# Epoch 18/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0111 - val_loss: 0.0117
# Epoch 19/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0113 - val_loss: 0.0124
# Epoch 20/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0113 - val_loss: 0.0114
# Epoch 21/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0109 - val_loss: 0.0117
# Epoch 22/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0110 - val_loss: 0.0114
# Epoch 23/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 24/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0109 - val_loss: 0.0135
# Epoch 25/50
# 79/79 [==============================] - 4s 52ms/step - loss: 0.0109 - val_loss: 0.0115
# Epoch 26/50
# 79/79 [==============================] - 5s 59ms/step - loss: 0.0107 - val_loss: 0.0111
# Epoch 27/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0108 - val_loss: 0.0110
# Epoch 28/50
# 79/79 [==============================] - 4s 46ms/step - loss: 0.0107 - val_loss: 0.0110
# Epoch 29/50
# 79/79 [==============================] - 4s 47ms/step - loss: 0.0107 - val_loss: 0.0115
# Epoch 30/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0107 - val_loss: 0.0111
# Epoch 31/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0106 - val_loss: 0.0124
# Epoch 32/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0106 - val_loss: 0.0110
# Epoch 33/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0106 - val_loss: 0.0108
# Epoch 34/50
# 79/79 [==============================] - 3s 40ms/step - loss: 0.0106 - val_loss: 0.0111
# Epoch 35/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 36/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0105 - val_loss: 0.0109
# Epoch 37/50
# 79/79 [==============================] - 3s 40ms/step - loss: 0.0104 - val_loss: 0.0107
# Epoch 38/50
# 79/79 [==============================] - 3s 40ms/step - loss: 0.0105 - val_loss: 0.0108
# Epoch 39/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0104 - val_loss: 0.0109
# Epoch 40/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0104 - val_loss: 0.0128
# Epoch 41/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0103 - val_loss: 0.0107
# Epoch 42/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0104 - val_loss: 0.0109
# Epoch 43/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0106 - val_loss: 0.0113
# Epoch 44/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0103 - val_loss: 0.0113
# Epoch 45/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0104 - val_loss: 0.0111
# Epoch 46/50
# 79/79 [==============================] - 3s 40ms/step - loss: 0.0103 - val_loss: 0.0107
# Epoch 47/50
# 79/79 [==============================] - 5s 61ms/step - loss: 0.0102 - val_loss: 0.0110
# Epoch 48/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0104 - val_loss: 0.0108
# Epoch 49/50
# 79/79 [==============================] - 3s 39ms/step - loss: 0.0102 - val_loss: 0.0108
# Epoch 50/50
# 79/79 [==============================] - 4s 50ms/step - loss: 0.0103 - val_loss: 0.0106

# %%
plot_loss(history)

scores = autoencoder.evaluate(x_test_noisy, x_test, verbose=2)
print("Test mse: %.5f" % (scores))
# Out:
# 313/313 - 1s - loss: 0.0106 - 916ms/epoch - 3ms/step
# Test mse: 0.01062

# %% [markdown]
# **[TO COMPLETE]** Check the result by plotting some input images and the corresponding denoised outputs.

# %%
decoded_imgs = autoencoder.predict(x_test_noisy)

plot_img(10, [x_test_noisy, x_test, decoded_imgs])
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# ## Exercise 5.6: Linear Autoencoder for sequences
#
# Let's define a linear autoencoder for sequences. In this case we will use the IMDB dataset (already introduced in HW4). To have a model that can be trained and tested in a reasonable time (and that works also with the memory limitation that we have in _Colab_), we will limit the number of training samples and test samples.

# %%
num_words = 100
(X_train, _), (X_test, _) = keras.datasets.imdb.load_data(num_words=num_words)

X_train=X_train[:10000]

(X_valid, X_test) = X_test[:1250], X_test[-1250:]

word_index = keras.datasets.imdb.get_word_index()

reverse_index = {word_id + 3: word for word, word_id in word_index.items()}
reverse_index[0] = "<pad>" # padding
reverse_index[1] = "<sos>" # start of sequence
reverse_index[2] = "<oov>" # out-of-vocabulary
reverse_index[3] = "<unk>" # unknown

def decode_review(word_ids):
    return " ".join([reverse_index.get(word_id, "<err>") for word_id in word_ids])

maxlen = 90
X_train_trim = keras.preprocessing.sequence.pad_sequences(X_train, maxlen=maxlen)
X_test_trim = keras.preprocessing.sequence.pad_sequences(X_test, maxlen=maxlen)
X_valid_trim = keras.preprocessing.sequence.pad_sequences(X_valid, maxlen=maxlen)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 [==============================] - 0s 0us/step

# %% [markdown]
# In this case, we want to use as input/target a one-hot representation for each word. To convert the index representation provided by IMDB dataset loader we use the to_categorical method to transform them in the corresponding one hot representation.

# %%
from tensorflow.keras.utils import to_categorical


X_train_one_hot=to_categorical(X_train_trim)
X_test_one_hot=to_categorical(X_test_trim)
X_valid_one_hot=to_categorical(X_valid_trim)

# %% [markdown]
# Define a linear shallow autoencoder for sequences. The structure will be similar to the model defined in Exercise 5.2, while the used encoding layer is defined by using `tf.keras.layers.SimpleRNN`. Note that it uses linear activations. The decoding layer exploits [tf.keras.layers.TimeDistributed](https://www.tensorflow.org/api_docs/python/tf/keras/layers/TimeDistributed) that allows using the same dense cell at each time step of the sequence.

# %%
inputs = tf.keras.layers.Input(shape=(maxlen, num_words))
encoded = tf.keras.layers.SimpleRNN(50, return_sequences=True, activation='linear')(inputs)

decoded = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(num_words, activation='linear'))(encoded)

sequence_autoencoder = tf.keras.models.Model(inputs, decoded)
encoder = tf.keras.models.Model(inputs, encoded)

sequence_autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=["CategoricalAccuracy"])

sequence_autoencoder.summary()
# Out:
# Model: "model_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 90, 100)]         0
#
#  simple_rnn (SimpleRNN)      (None, 90, 50)            7550
#
#  time_distributed (TimeDistr  (None, 90, 100)          5100
#  ibuted)
#
# =================================================================
# Total params: 12,650
# Trainable params: 12,650
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = sequence_autoencoder.fit(X_train_one_hot, X_train_one_hot, epochs=50, batch_size=128, shuffle=True, validation_data=(X_valid_one_hot, X_valid_one_hot))
# Out:
# Epoch 1/50
# 79/79 [==============================] - 8s 85ms/step - loss: 0.1936 - categorical_accuracy: 0.1389 - val_loss: 0.0905 - val_categorical_accuracy: 0.3408
# Epoch 2/50
# 79/79 [==============================] - 7s 94ms/step - loss: 0.0748 - categorical_accuracy: 0.4405 - val_loss: 0.0671 - val_categorical_accuracy: 0.4790
# Epoch 3/50
# 79/79 [==============================] - 6s 79ms/step - loss: 0.0621 - categorical_accuracy: 0.5108 - val_loss: 0.0595 - val_categorical_accuracy: 0.5138
# Epoch 4/50
# 79/79 [==============================] - 6s 79ms/step - loss: 0.0545 - categorical_accuracy: 0.5441 - val_loss: 0.0521 - val_categorical_accuracy: 0.5574
# Epoch 5/50
# 79/79 [==============================] - 6s 79ms/step - loss: 0.0496 - categorical_accuracy: 0.5774 - val_loss: 0.0507 - val_categorical_accuracy: 0.5825
# Epoch 6/50
# 79/79 [==============================] - 6s 79ms/step - loss: 0.0462 - categorical_accuracy: 0.6023 - val_loss: 0.0446 - val_categorical_accuracy: 0.6242
# Epoch 7/50
# 79/79 [==============================] - 6s 78ms/step - loss: 0.0420 - categorical_accuracy: 0.6384 - val_loss: 0.0407 - val_categorical_accuracy: 0.6278
# Epoch 8/50
# 79/79 [==============================] - 6s 79ms/step - loss: 0.0386 - categorical_accuracy: 0.6570 - val_loss: 0.0376 - val_categorical_accuracy: 0.6778
# Epoch 9/50
# 79/79 [==============================] - 6s 80ms/step - loss: 0.0354 - categorical_accuracy: 0.6790 - val_loss: 0.0345 - val_categorical_accuracy: 0.6791
# Epoch 10/50
# 79/79 [==============================] - 6s 79ms/step - loss: 0.0327 - categorical_accuracy: 0.6973 - val_loss: 0.0321 - val_categorical_accuracy: 0.7030
# Epoch 11/50
# 79/79 [==============================] - 6s 80ms/step - loss: 0.0305 - categorical_accuracy: 0.7242 - val_loss: 0.0298 - val_categorical_accuracy: 0.7333
# Epoch 12/50
# 79/79 [==============================] - 6s 79ms/step - loss: 0.0283 - categorical_accuracy: 0.7453 - val_loss: 0.0276 - val_categorical_accuracy: 0.7519
# Epoch 13/50
# 79/79 [==============================] - 7s 84ms/step - loss: 0.0263 - categorical_accuracy: 0.7679 - val_loss: 0.0257 - val_categorical_accuracy: 0.7718
# Epoch 14/50
# 79/79 [==============================] - 6s 79ms/step - loss: 0.0250 - categorical_accuracy: 0.7908 - val_loss: 0.0249 - val_categorical_accuracy: 0.7934
# Epoch 15/50
# 79/79 [==============================] - 7s 88ms/step - loss: 0.0237 - categorical_accuracy: 0.8042 - val_loss: 0.0234 - val_categorical_accuracy: 0.8113
# Epoch 16/50
# 79/79 [==============================] - 6s 80ms/step - loss: 0.0226 - categorical_accuracy: 0.8211 - val_loss: 0.0225 - val_categorical_accuracy: 0.8235
# Epoch 17/50
# 79/79 [==============================] - 6s 78ms/step - loss: 0.0218 - categorical_accuracy: 0.8365 - val_loss: 0.0218 - val_categorical_accuracy: 0.8396
# Epoch 18/50
# 79/79 [==============================] - 6s 79ms/step - loss: 0.0211 - categorical_accuracy: 0.8512 - val_loss: 0.0209 - val_categorical_accuracy: 0.8488
# Epoch 19/50
# 79/79 [==============================] - 6s 79ms/step - loss: 0.0202 - categorical_accuracy: 0.8588 - val_loss: 0.0202 - val_categorical_accuracy: 0.8600
# Epoch 20/50
# 79/79 [==============================] - 6s 79ms/step - loss: 0.0196 - categorical_accuracy: 0.8700 - val_loss: 0.0194 - val_categorical_accuracy: 0.8712
# Epoch 21/50
# 79/79 [==============================] - 6s 79ms/step - loss: 0.0189 - categorical_accuracy: 0.8781 - val_loss: 0.0189 - val_categorical_accuracy: 0.8799
# Epoch 22/50
# 79/79 [==============================] - 6s 79ms/step - loss: 0.0183 - categorical_accuracy: 0.8876 - val_loss: 0.0182 - val_categorical_accuracy: 0.8879
# Epoch 23/50
# 79/79 [==============================] - 6s 80ms/step - loss: 0.0178 - categorical_accuracy: 0.8930 - val_loss: 0.0178 - val_categorical_accuracy: 0.8941
# Epoch 24/50
# 79/79 [==============================] - 6s 80ms/step - loss: 0.0174 - categorical_accuracy: 0.8983 - val_loss: 0.0175 - val_categorical_accuracy: 0.8992
# Epoch 25/50
# 79/79 [==============================] - 6s 79ms/step - loss: 0.0171 - categorical_accuracy: 0.9025 - val_loss: 0.0172 - val_categorical_accuracy: 0.9029
# Epoch 26/50
# 79/79 [==============================] - 6s 79ms/step - loss: 0.0168 - categorical_accuracy: 0.9058 - val_loss: 0.0169 - val_categorical_accuracy: 0.9058
# Epoch 27/50
# 79/79 [==============================] - 6s 79ms/step - loss: 0.0168 - categorical_accuracy: 0.9097 - val_loss: 0.0169 - val_categorical_accuracy: 0.9091
# Epoch 28/50
# 79/79 [==============================] - 6s 81ms/step - loss: 0.0164 - categorical_accuracy: 0.9110 - val_loss: 0.0165 - val_categorical_accuracy: 0.9109
# Epoch 29/50
# 79/79 [==============================] - 6s 81ms/step - loss: 0.0161 - categorical_accuracy: 0.9133 - val_loss: 0.0162 - val_categorical_accuracy: 0.9135
# Epoch 30/50
# 79/79 [==============================] - 6s 80ms/step - loss: 0.0157 - categorical_accuracy: 0.9163 - val_loss: 0.0157 - val_categorical_accuracy: 0.9163
# Epoch 31/50
# 79/79 [==============================] - 6s 80ms/step - loss: 0.0153 - categorical_accuracy: 0.9187 - val_loss: 0.0155 - val_categorical_accuracy: 0.9184
# Epoch 32/50
# 79/79 [==============================] - 6s 80ms/step - loss: 0.0151 - categorical_accuracy: 0.9204 - val_loss: 0.0153 - val_categorical_accuracy: 0.9195
# Epoch 33/50
# 79/79 [==============================] - 7s 82ms/step - loss: 0.0149 - categorical_accuracy: 0.9214 - val_loss: 0.0151 - val_categorical_accuracy: 0.9206
# Epoch 34/50
# 79/79 [==============================] - 6s 80ms/step - loss: 0.0148 - categorical_accuracy: 0.9223 - val_loss: 0.0149 - val_categorical_accuracy: 0.9213
# Epoch 35/50
# 79/79 [==============================] - 7s 94ms/step - loss: 0.0146 - categorical_accuracy: 0.9231 - val_loss: 0.0147 - val_categorical_accuracy: 0.9221
# Epoch 36/50
# 79/79 [==============================] - 10s 122ms/step - loss: 0.0144 - categorical_accuracy: 0.9238 - val_loss: 0.0146 - val_categorical_accuracy: 0.9228
# Epoch 37/50
# 79/79 [==============================] - 7s 88ms/step - loss: 0.0143 - categorical_accuracy: 0.9244 - val_loss: 0.0144 - val_categorical_accuracy: 0.9234
# Epoch 38/50
# 79/79 [==============================] - 6s 80ms/step - loss: 0.0141 - categorical_accuracy: 0.9249 - val_loss: 0.0143 - val_categorical_accuracy: 0.9237
# Epoch 39/50
# 79/79 [==============================] - 8s 101ms/step - loss: 0.0140 - categorical_accuracy: 0.9254 - val_loss: 0.0141 - val_categorical_accuracy: 0.9242
# Epoch 40/50
# 79/79 [==============================] - 8s 106ms/step - loss: 0.0138 - categorical_accuracy: 0.9258 - val_loss: 0.0140 - val_categorical_accuracy: 0.9248
# Epoch 41/50
# 79/79 [==============================] - 9s 116ms/step - loss: 0.0137 - categorical_accuracy: 0.9262 - val_loss: 0.0138 - val_categorical_accuracy: 0.9251
# Epoch 42/50
# 79/79 [==============================] - 9s 110ms/step - loss: 0.0135 - categorical_accuracy: 0.9264 - val_loss: 0.0137 - val_categorical_accuracy: 0.9253
# Epoch 43/50
# 79/79 [==============================] - 7s 94ms/step - loss: 0.0134 - categorical_accuracy: 0.9266 - val_loss: 0.0136 - val_categorical_accuracy: 0.9255
# Epoch 44/50
# 79/79 [==============================] - 7s 83ms/step - loss: 0.0133 - categorical_accuracy: 0.9269 - val_loss: 0.0134 - val_categorical_accuracy: 0.9257
# Epoch 45/50
# 79/79 [==============================] - 6s 82ms/step - loss: 0.0132 - categorical_accuracy: 0.9271 - val_loss: 0.0133 - val_categorical_accuracy: 0.9259
# Epoch 46/50
# 79/79 [==============================] - 6s 81ms/step - loss: 0.0130 - categorical_accuracy: 0.9272 - val_loss: 0.0132 - val_categorical_accuracy: 0.9261
# Epoch 47/50
# 79/79 [==============================] - 6s 79ms/step - loss: 0.0129 - categorical_accuracy: 0.9274 - val_loss: 0.0131 - val_categorical_accuracy: 0.9263
# Epoch 48/50
# 79/79 [==============================] - 8s 97ms/step - loss: 0.0128 - categorical_accuracy: 0.9275 - val_loss: 0.0130 - val_categorical_accuracy: 0.9265
# Epoch 49/50
# 79/79 [==============================] - 7s 84ms/step - loss: 0.0127 - categorical_accuracy: 0.9276 - val_loss: 0.0129 - val_categorical_accuracy: 0.9266
# Epoch 50/50
# 79/79 [==============================] - 7s 92ms/step - loss: 0.0126 - categorical_accuracy: 0.9277 - val_loss: 0.0128 - val_categorical_accuracy: 0.9266

# %% [markdown]
# Let's plot the accuracy and the loss trends and check the reconstruction capability of the model by plotting the reconstruction of a test sample

# %%
def plot_categorical_accuracy(history):
  plt.figure(figsize=(10,6))
  plt.plot(history.epoch,history.history['categorical_accuracy'])
  plt.plot(history.epoch,history.history['val_categorical_accuracy'])
  plt.title('accuracy')

plot_loss(history)

plot_categorical_accuracy(history)

scores = sequence_autoencoder.evaluate(X_test_one_hot, X_test_one_hot, verbose=2)
print("%s: %.2f%%" % (sequence_autoencoder.metrics_names[1], scores[1]*100))
# Out:
# 40/40 - 1s - loss: 0.0127 - categorical_accuracy: 0.9270 - 538ms/epoch - 13ms/step
# categorical_accuracy: 92.70%

# %%
decoded_text = sequence_autoencoder.predict(X_test_one_hot)
decode_index= np.argmax(decoded_text[500], axis=1)
input_text= np.argmax(X_test_one_hot[500], axis=1)

print(decode_review(input_text))
print(decode_review(decode_index))
# Out:
# 40/40 [==============================] - 1s 9ms/step
# than a <oov> <oov> that are <oov> in all of that time but that <oov> the <oov> is <oov> a very <oov> film in just about <oov> <oov> <oov> <oov> as some other <oov> have <oov> out it <oov> like <oov> <oov> of the film are <oov> <oov> there <oov> other <oov> <oov> <oov> are <oov> <oov> in the <oov> <oov> this is a really bad film that <oov> <oov> <oov> than its <oov> of <oov> <oov> i <oov> it <oov> out of <oov> and i <oov> <oov> very <oov>
# was a <oov> <oov> that i <oov> in all of that time but that <oov> the <oov> is <oov> a very <oov> film in just about <oov> <oov> <oov> <oov> as some in <oov> have <oov> out have <oov> really <oov> <oov> of the film most <oov> <oov> there <oov> of <oov> <oov> <oov> with <oov> <oov> in the <oov> <oov> this is a really from film that <oov> <oov> <oov> with a <oov> of <oov> <oov> i <oov> a <oov> out of <oov> and i <oov> <oov> very <oov>

# %% [markdown]
# ##[TO COMPLETE] Exercise 5.7: Non-Linear Autoencoder for sequences
# **[TO COMPLETE]**: Replicate the code of the above exercise, but instead of using a simpleRNN with linear activation do the same  using  non-linear activation functions and using an LSTM layer. Choose the most appropriate non-linear function, and motivate your choice. Then discuss the results in relation to those obtained by the linear autoencoder for sequences.
#
# Hint: using a non-linear function also in the dense layer after the RNN/LSTM one will help to obtain better results. The choice of this function should be based on the type of output data.

# %% [markdown]
# Obviously, since the output is made out of one-hot encoded vectors, the best choice for a loss function is categorical cross-entropy, paired with softmax activation.For the LSTm layer, I also preffered softmax.

# %%
inputs = tf.keras.layers.Input(shape=(maxlen, num_words))
encoded = tf.keras.layers.LSTM(50, return_sequences=True, activation='sigmoid')(inputs)

decoded = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(num_words, activation='softmax'))(encoded)

sequence_autoencoder = tf.keras.models.Model(inputs, decoded)
encoder = tf.keras.models.Model(inputs, encoded)

sequence_autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='CategoricalCrossentropy', metrics=["CategoricalAccuracy"])

sequence_autoencoder.summary()

history = sequence_autoencoder.fit(X_train_one_hot, X_train_one_hot, epochs=50, batch_size=128, shuffle=True, validation_data=(X_valid_one_hot, X_valid_one_hot))
# Out:
# Model: "model_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 90, 100)]         0
#
#  lstm (LSTM)                 (None, 90, 50)            30200
#
#  time_distributed_1 (TimeDis  (None, 90, 100)          5100
#  tributed)
#
# =================================================================
# Total params: 35,300
# Trainable params: 35,300
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 79/79 [==============================] - 14s 160ms/step - loss: 3.5419 - categorical_accuracy: 0.3244 - val_loss: 2.8570 - val_categorical_accuracy: 0.4573
# Epoch 2/50
# 79/79 [==============================] - 12s 151ms/step - loss: 2.7797 - categorical_accuracy: 0.4715 - val_loss: 2.7774 - val_categorical_accuracy: 0.4620
# Epoch 3/50
# 79/79 [==============================] - 12s 153ms/step - loss: 2.6755 - categorical_accuracy: 0.4716 - val_loss: 2.6181 - val_categorical_accuracy: 0.4622
# Epoch 4/50
# 79/79 [==============================] - 12s 156ms/step - loss: 2.4372 - categorical_accuracy: 0.4718 - val_loss: 2.2942 - val_categorical_accuracy: 0.4622
# Epoch 5/50
# 79/79 [==============================] - 13s 170ms/step - loss: 2.0568 - categorical_accuracy: 0.4722 - val_loss: 1.8570 - val_categorical_accuracy: 0.4715
# Epoch 6/50
# 79/79 [==============================] - 12s 153ms/step - loss: 1.6027 - categorical_accuracy: 0.6209 - val_loss: 1.3988 - val_categorical_accuracy: 0.7387
# Epoch 7/50
# 79/79 [==============================] - 12s 152ms/step - loss: 1.1900 - categorical_accuracy: 0.7766 - val_loss: 1.0318 - val_categorical_accuracy: 0.7993
# Epoch 8/50
# 79/79 [==============================] - 12s 152ms/step - loss: 0.8755 - categorical_accuracy: 0.8281 - val_loss: 0.7599 - val_categorical_accuracy: 0.8486
# Epoch 9/50
# 79/79 [==============================] - 12s 157ms/step - loss: 0.6444 - categorical_accuracy: 0.8745 - val_loss: 0.5590 - val_categorical_accuracy: 0.8952
# Epoch 10/50
# 79/79 [==============================] - 12s 152ms/step - loss: 0.4730 - categorical_accuracy: 0.9113 - val_loss: 0.4092 - val_categorical_accuracy: 0.9247
# Epoch 11/50
# 79/79 [==============================] - 12s 153ms/step - loss: 0.3458 - categorical_accuracy: 0.9453 - val_loss: 0.2986 - val_categorical_accuracy: 0.9632
# Epoch 12/50
# 79/79 [==============================] - 12s 154ms/step - loss: 0.2525 - categorical_accuracy: 0.9723 - val_loss: 0.2183 - val_categorical_accuracy: 0.9780
# Epoch 13/50
# 79/79 [==============================] - 12s 154ms/step - loss: 0.1853 - categorical_accuracy: 0.9818 - val_loss: 0.1611 - val_categorical_accuracy: 0.9846
# Epoch 14/50
# 79/79 [==============================] - 16s 204ms/step - loss: 0.1375 - categorical_accuracy: 0.9899 - val_loss: 0.1205 - val_categorical_accuracy: 0.9924
# Epoch 15/50
# 79/79 [==============================] - 12s 153ms/step - loss: 0.1036 - categorical_accuracy: 0.9955 - val_loss: 0.0919 - val_categorical_accuracy: 0.9976
# Epoch 16/50
# 79/79 [==============================] - 12s 153ms/step - loss: 0.0798 - categorical_accuracy: 0.9985 - val_loss: 0.0716 - val_categorical_accuracy: 0.9986
# Epoch 17/50
# 79/79 [==============================] - 12s 153ms/step - loss: 0.0629 - categorical_accuracy: 0.9987 - val_loss: 0.0571 - val_categorical_accuracy: 0.9986
# Epoch 18/50
# 79/79 [==============================] - 12s 158ms/step - loss: 0.0507 - categorical_accuracy: 0.9987 - val_loss: 0.0465 - val_categorical_accuracy: 0.9986
# Epoch 19/50
# 79/79 [==============================] - 12s 157ms/step - loss: 0.0417 - categorical_accuracy: 0.9995 - val_loss: 0.0386 - val_categorical_accuracy: 1.0000
# Epoch 20/50
# 79/79 [==============================] - 12s 153ms/step - loss: 0.0349 - categorical_accuracy: 1.0000 - val_loss: 0.0326 - val_categorical_accuracy: 1.0000
# Epoch 21/50
# 79/79 [==============================] - 12s 153ms/step - loss: 0.0297 - categorical_accuracy: 1.0000 - val_loss: 0.0279 - val_categorical_accuracy: 1.0000
# Epoch 22/50
# 79/79 [==============================] - 13s 171ms/step - loss: 0.0256 - categorical_accuracy: 1.0000 - val_loss: 0.0242 - val_categorical_accuracy: 1.0000
# Epoch 23/50
# 79/79 [==============================] - 12s 153ms/step - loss: 0.0223 - categorical_accuracy: 1.0000 - val_loss: 0.0212 - val_categorical_accuracy: 1.0000
# Epoch 24/50
# 79/79 [==============================] - 12s 154ms/step - loss: 0.0196 - categorical_accuracy: 1.0000 - val_loss: 0.0187 - val_categorical_accuracy: 1.0000
# Epoch 25/50
# 79/79 [==============================] - 12s 153ms/step - loss: 0.0173 - categorical_accuracy: 1.0000 - val_loss: 0.0166 - val_categorical_accuracy: 1.0000
# Epoch 26/50
# 79/79 [==============================] - 12s 154ms/step - loss: 0.0155 - categorical_accuracy: 1.0000 - val_loss: 0.0149 - val_categorical_accuracy: 1.0000
# Epoch 27/50
# 79/79 [==============================] - 12s 154ms/step - loss: 0.0139 - categorical_accuracy: 1.0000 - val_loss: 0.0134 - val_categorical_accuracy: 1.0000
# Epoch 28/50
# 79/79 [==============================] - 12s 154ms/step - loss: 0.0126 - categorical_accuracy: 1.0000 - val_loss: 0.0121 - val_categorical_accuracy: 1.0000
# Epoch 29/50
# 79/79 [==============================] - 12s 154ms/step - loss: 0.0114 - categorical_accuracy: 1.0000 - val_loss: 0.0110 - val_categorical_accuracy: 1.0000
# Epoch 30/50
# 79/79 [==============================] - 12s 154ms/step - loss: 0.0104 - categorical_accuracy: 1.0000 - val_loss: 0.0101 - val_categorical_accuracy: 1.0000
# Epoch 31/50
# 79/79 [==============================] - 12s 153ms/step - loss: 0.0095 - categorical_accuracy: 1.0000 - val_loss: 0.0092 - val_categorical_accuracy: 1.0000
# Epoch 32/50
# 79/79 [==============================] - 12s 153ms/step - loss: 0.0087 - categorical_accuracy: 1.0000 - val_loss: 0.0085 - val_categorical_accuracy: 1.0000
# Epoch 33/50
# 79/79 [==============================] - 12s 153ms/step - loss: 0.0080 - categorical_accuracy: 1.0000 - val_loss: 0.0078 - val_categorical_accuracy: 1.0000
# Epoch 34/50
# 79/79 [==============================] - 12s 153ms/step - loss: 0.0074 - categorical_accuracy: 1.0000 - val_loss: 0.0072 - val_categorical_accuracy: 1.0000
# Epoch 35/50
# 79/79 [==============================] - 12s 152ms/step - loss: 0.0068 - categorical_accuracy: 1.0000 - val_loss: 0.0067 - val_categorical_accuracy: 1.0000
# Epoch 36/50
# 79/79 [==============================] - 12s 152ms/step - loss: 0.0063 - categorical_accuracy: 1.0000 - val_loss: 0.0062 - val_categorical_accuracy: 1.0000
# Epoch 37/50
# 79/79 [==============================] - 12s 152ms/step - loss: 0.0059 - categorical_accuracy: 1.0000 - val_loss: 0.0058 - val_categorical_accuracy: 1.0000
# Epoch 38/50
# 79/79 [==============================] - 12s 152ms/step - loss: 0.0055 - categorical_accuracy: 1.0000 - val_loss: 0.0054 - val_categorical_accuracy: 1.0000
# Epoch 39/50
# 79/79 [==============================] - 13s 170ms/step - loss: 0.0051 - categorical_accuracy: 1.0000 - val_loss: 0.0050 - val_categorical_accuracy: 1.0000
# Epoch 40/50
# 79/79 [==============================] - 12s 152ms/step - loss: 0.0048 - categorical_accuracy: 1.0000 - val_loss: 0.0047 - val_categorical_accuracy: 1.0000
# Epoch 41/50
# 79/79 [==============================] - 12s 153ms/step - loss: 0.0045 - categorical_accuracy: 1.0000 - val_loss: 0.0044 - val_categorical_accuracy: 1.0000
# Epoch 42/50
# 79/79 [==============================] - 12s 154ms/step - loss: 0.0042 - categorical_accuracy: 1.0000 - val_loss: 0.0041 - val_categorical_accuracy: 1.0000
# Epoch 43/50
# 79/79 [==============================] - 12s 152ms/step - loss: 0.0039 - categorical_accuracy: 1.0000 - val_loss: 0.0039 - val_categorical_accuracy: 1.0000
# Epoch 44/50
# 79/79 [==============================] - 12s 153ms/step - loss: 0.0037 - categorical_accuracy: 1.0000 - val_loss: 0.0036 - val_categorical_accuracy: 1.0000
# Epoch 45/50
# 79/79 [==============================] - 12s 152ms/step - loss: 0.0035 - categorical_accuracy: 1.0000 - val_loss: 0.0034 - val_categorical_accuracy: 1.0000
# Epoch 46/50
# 79/79 [==============================] - 12s 152ms/step - loss: 0.0033 - categorical_accuracy: 1.0000 - val_loss: 0.0032 - val_categorical_accuracy: 1.0000
# Epoch 47/50
# 79/79 [==============================] - 12s 153ms/step - loss: 0.0031 - categorical_accuracy: 1.0000 - val_loss: 0.0030 - val_categorical_accuracy: 1.0000
# Epoch 48/50
# 79/79 [==============================] - 12s 152ms/step - loss: 0.0029 - categorical_accuracy: 1.0000 - val_loss: 0.0029 - val_categorical_accuracy: 1.0000
# Epoch 49/50
# 79/79 [==============================] - 12s 153ms/step - loss: 0.0027 - categorical_accuracy: 1.0000 - val_loss: 0.0027 - val_categorical_accuracy: 1.0000
# Epoch 50/50
# 79/79 [==============================] - 12s 154ms/step - loss: 0.0026 - categorical_accuracy: 1.0000 - val_loss: 0.0025 - val_categorical_accuracy: 1.0000

# %%
plot_loss(history)

plot_categorical_accuracy(history)

scores = sequence_autoencoder.evaluate(X_test_one_hot, X_test_one_hot, verbose=2)
print("%s: %.2f%%" % (sequence_autoencoder.metrics_names[1], scores[1]*100))
# Out:
# 40/40 - 1s - loss: 0.0025 - categorical_accuracy: 1.0000 - 789ms/epoch - 20ms/step
# categorical_accuracy: 100.00%

# %% [markdown]
# As you can see, this model slightly outperforms the linear one in this particular case. However, I personally believe these results come from the fact that the distribution of words is really imbalanced.

# %%
scores = sequence_autoencoder.evaluate(X_test_one_hot, X_test_one_hot, verbose=2)
print("%s: %.2f%%" % (sequence_autoencoder.metrics_names[1], scores[1]*100))
# Out:
# 40/40 - 1s - loss: 0.0025 - categorical_accuracy: 1.0000 - 769ms/epoch - 19ms/step
# categorical_accuracy: 100.00%
